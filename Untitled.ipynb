# %%
#todo: one dict data structure or object 
from clibv2 import *  #%matplotlib qt#user_path = !eval echo ~$USER

# %%
'''reading values from TXT files'''
try:
    vals = get_values_from_textfiles() #vals = get_values_from_textfiles('/Users/salmasi/LUND/WC15Co-Ti64-200um200um/1000C2/')
except:
    print('Error reading text files')
else:
    print('Text files are loaded in memory')
# Out:
# /Volumes/exFAT/LUND/REALPCBN/test
# Text files are loaded in memory

# %%
'''Selecting time steps'''
try:
    times = vals[4]
    tStamp, nearestTime = get_timeStamp(times) 
except:
    print('Selected simulation time is not in range')
else:
    print('Selected time is in range, timeStamp is {}'.format(tStamp))
'''get values of selected time steps from Data'''
tStamp_vals = get_values_of_timeStamp(vals,tStamp)
uf,uf_dict = calculate_u_fractions(tStamp_vals[0],vals[10],vals[2])
# todo: add uf_calc to get_values_of_timeStamp
'''plot limits'''
x1 = float(input('xlims =/{},{}/x1?/:'.format(tStamp_vals[3][0],tStamp_vals[3][-1])))
x2 = float(input('xlims =/{},{}/x2?/:'.format(tStamp_vals[3][0],tStamp_vals[3][-1])))
# Out:
# Selected time is in range, timeStamp is 21

# %%
'''Selecting time steps'''
try:
    times = vals[4]
    tStamp, nearestTime = get_timeStamp(times) 
except:
    print('Selected simulation time is not in range')
else:
    print('Selected time is in range, timeStamp is {}'.format(tStamp))
'''get values of selected time steps from Data'''
tStamp_vals = get_values_of_timeStamp(vals,tStamp)
uf,uf_dict = calculate_u_fractions(tStamp_vals[0],vals[10],vals[2])
# todo: add uf_calc to get_values_of_timeStamp
'''plot limits'''
x1 = float(input('xlims =/{},{}/x1?/:'.format(tStamp_vals[3][0],tStamp_vals[3][-1])))
x2 = float(input('xlims =/{},{}/x2?/:'.format(tStamp_vals[3][0],tStamp_vals[3][-1])))
# Out:
# Selected time is in range, timeStamp is 21

# %%
'''Pre settings'''
phase_change = [('BCC_A2','W',1),('FCC_A1','C',0.03)] #phase_change = [('BCC_A2','W',1),('FCC_A1','C',0.03)]#,('FCC_A1','Ti',0.05),('FCC_A1','Al',0.05)]
database,activityRefs,phsToSuspend = 'tcfe9',[],[] #phsToSuspend =['gas']#phsToSuspend =['graphite']
name_paires = [('BCC_A2#1','Ti64 BCC'),('FCC_A1#1','Co FCC'), ('MC_SHP#1','WC'),('M6C#1','Eta M6'),('BCC_A2-W','W BCC'),('FCC_A1-CTI','TiC'),('FCC_A1-CAL','AlC'),('FCC_A1-ALC','AlC'),('LIQUID#1','LIQUID'),('FCC_A1-TIC','TiC')]
# todo : automatic alternating

# %%
tStamp_vals_summed = add_phs_compositionDets_DICTRA(tStamp_vals)

# %%
'''Thermodynaic calculations of the timestamp'''
T,subidx,elnames,pth,poly3_file = vals[9],vals[10],vals[2],vals[0],False
tStamp_tcProc_vals = tccalc(tStamp_vals, database, phsToSuspend, activityRefs, T, elnames, pth, poly3_file)
# todo : calculate u-fractions
trimed_tcCalculated_vals = trim_tcCalculated_values(tStamp_vals,tStamp_tcProc_vals,elnames,subidx)
'''Correct phase indices to account for carbides and nitrides or any change in composition sets'''
_,corrected_phase_indices_vals=correct_phase_indices(trimed_tcCalculated_vals,phase_change)
summed_npms_dict = add_composition_sets(corrected_phase_indices_vals)
name_changed_npms_dict = ph_namechange(summed_npms_dict,name_paires)
# Out:
# input OK
# correcting indices
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-e71e1e9dd71d> in <module>
#       5 trimed_tcCalculated_vals = trim_tcCalculated_values(tStamp_vals,tStamp_tcProc_vals,elnames,subidx)
#       6 '''Correct phase indices to account for carbides and nitrides or any change in composition sets'''
# ----> 7 _,corrected_phase_indices_vals=correct_phase_indices(trimed_tcCalculated_vals,phase_change)
#       8 summed_npms_dict = add_composition_sets(corrected_phase_indices_vals)
#       9 name_changed_npms_dict = ph_namechange(summed_npms_dict,name_paires)
#
# /Volumes/exFAT/LUND/clibv2.py in correct_phase_indices(*argv)
#     464                     sorted_xs_phase_in_point = np.flip(sorted(phX_in_points[phase][point,:]))
#     465                     sorted_elnames = elnames[sorted_indices]
# --> 466                     search_element_index_sorted = np.where( sorted_elnames== search_element )[0][0]
#     467                     if cutoff > 0 and cutoff<1:
#     468                         if sorted_xs_phase_in_point[search_element_index_sorted] >= cutoff:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import matplotlib.pyplot as plt
plot_list(tStamp_vals[3],tStamp_vals[1],tStamp_vals[4],'DICTRA TXT FILES, t={}'.format(nearestTime),(x1,x2))
plot_dict(tStamp_vals[3], tStamp_vals_summed, tStamp_vals_summed.keys(), 'DICTRA TXT FILES, Composition sets are summed, t={}'.format(nearestTime),(x1,x2))    
plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[2], trimed_tcCalculated_vals[2].keys(), 'TC calculated values, NPM, t={}'.format(nearestTime), (x1,x2))
plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[3], trimed_tcCalculated_vals[3].keys(), 'TC calculated values, VPV, t={}'.format(nearestTime), (x1,x2))
plot_dict(trimed_tcCalculated_vals[0], summed_npms_dict, summed_npms_dict.keys(), 'TC calculated values,summed NPMs, t={}'.format(nearestTime), (x1,x2))
plot_dict(trimed_tcCalculated_vals[0], name_changed_npms_dict, name_changed_npms_dict.keys(), 'TC calculated values,summed NPMs changed names, t={}'.format(nearestTime), (x1,x2))
plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[1], trimed_tcCalculated_vals[11], 'TC calculated values, MFs , t={}'.format(nearestTime), (x1,x2))
plot_dict(trimed_tcCalculated_vals[0], uf_dict, uf_dict.keys(), 'TC calculated values, UFs , t={}'.format(nearestTime), (x1,x2))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7cb3baf4cfc7> in <module>
#       4 plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[2], trimed_tcCalculated_vals[2].keys(), 'TC calculated values, NPM, t={}'.format(nearestTime), (x1,x2))
#       5 plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[3], trimed_tcCalculated_vals[3].keys(), 'TC calculated values, VPV, t={}'.format(nearestTime), (x1,x2))
# ----> 6 plot_dict(trimed_tcCalculated_vals[0], summed_npms_dict, summed_npms_dict.keys(), 'TC calculated values,summed NPMs, t={}'.format(nearestTime), (x1,x2))
#       7 plot_dict(trimed_tcCalculated_vals[0], name_changed_npms_dict, name_changed_npms_dict.keys(), 'TC calculated values,summed NPMs changed names, t={}'.format(nearestTime), (x1,x2))
#       8 plot_dict(trimed_tcCalculated_vals[0], trimed_tcCalculated_vals[1], trimed_tcCalculated_vals[11], 'TC calculated values, MFs , t={}'.format(nearestTime), (x1,x2))
#
# NameError: name 'summed_npms_dict' is not defined
